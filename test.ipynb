# %%
import pandas

# %%
url = 'http://xiu.iqixiu.cn/%7B9468e483-ee5a-4e84-a09c-208bef32b48e%7D.htm'
table = pandas.read_html(url)

# %%
table
# Out:
# [                 0    1     2            3                        4  \
#  0    宜昌市504家汽修厂通讯录  NaN   NaN          NaN                      NaN
#  1               序号  所在市   所在区         单位名称                     单位地址
#  2                1  宜昌市   西陵区         顺达汽修               西陵二路103号附近
#  3                2  宜昌市   西陵区         三和汽修       西陵二路60号(迎福餐馆西侧80米)
#  4                3  宜昌市   西陵区         鹏程汽修                  东山大道37号
#  5                4  宜昌市   西陵区         恒信汽修                   朝阳路58号
#  6                5  宜昌市   西陵区         永发汽修  发展大道41号鑫昌汽配城A19号和32-**号
#  7                6  宜昌市   西陵区         鹏飞汽修           沿江大道38号03号市一中旁
#  8                7  宜昌市   西陵区         福盛汽修                西陵二路39-1号
#  9                8  宜昌市   西陵区         通顺汽修                  北苑路6号附近
#  10               9  宜昌市   西陵区         志成汽修                  港窑路9-*号
#  11              10  宜昌市   西陵区         海洲汽修                  沿江大道38号
#  12              11  宜昌市   西陵区         超威汽修                  沿江大道38号
# ...
